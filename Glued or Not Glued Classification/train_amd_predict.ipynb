# %%
from ultralytics import YOLO

model = YOLO('yolov8n-cls.pt')  # load a pretrained model (recommended for training)

model.train(data=r'E:\comp_vision\YOLOLO\data\images', epochs=20, imgsz=640)
# Out:
# Ultralytics YOLOv8.1.0 🚀 Python-3.10.9 torch-2.1.1+cpu CPU (Intel Xeon W-2245 3.90GHz)
# ...

# %%
from ultralytics import YOLO

# Load a model
model = YOLO('yolov8n-cls.pt')  # load an official model
model = YOLO(r'E:\comp_vision\YOLOLO\runs\classify\train9\weights\last.pt')  # load a custom model

# Predict with the model
results = model(r"C:\Users\167093\Downloads\MicrosoftTeams-image (15).png")  # predict on an image
# Out:
# image 1/1 C:\Users\167093\Downloads\MicrosoftTeams-image (15).png: 640x640 Glued 0.96, NotGlued 0.04, 34.0ms
# Speed: 25.5ms preprocess, 34.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)

# %%
from PIL import Image
from torchvision.transforms import ToTensor
from rembg import remove
import torchvision
import torch
from ultralytics import YOLO
import matplotlib.pyplot as plt


#Load the model
model = YOLO('yolov8n-cls.pt')  # load an official model
model = YOLO(r'E:\comp_vision\YOLOLO\runs\classify\train9\weights\last.pt')  # load a custom model

# Load the image
image_path = r"C:\Users\167093\Downloads\new_test\MicrosoftTeams-image (34).png"
image = Image.open(image_path)

output = remove(image)

plt.imshow(output)
# Remove the alpha channel if present
if output.mode == 'RGBA':
    image1 = output.convert('RGB')

else:
    image1=output

# Resize the image
resized_img = image1.resize((640, 640))

#give prediction
results = model(resized_img)
# Out:
# 0: 640x640 Glued 1.00, NotGlued 0.00, 31.0ms
# Speed: 8.0ms preprocess, 31.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)

# %%
from PIL import Image
from torchvision.transforms import ToTensor
from rembg import remove
import torchvision
import torch
from ultralytics import YOLO
import matplotlib.pyplot as plt
import os

# Load the model
model = YOLO(r'E:\comp_vision\YOLOLO\runs\classify\train9\weights\last.pt')  # load a custom model

# Folder containing test images
test_folder = r"C:\Users\167093\Downloads\new_test"

# Iterate through each file in the folder
for filename in os.listdir(test_folder):
    if filename.endswith(".png") or filename.endswith(".jpg"):
        # Load the image
        image_path = os.path.join(test_folder, filename)
        image = Image.open(image_path)

        # Perform background removal
        output = remove(image)

        # Remove the alpha channel if present
        if output.mode == 'RGBA':
            image1 = output.convert('RGB')
        else:
            image1 = output

        # Resize the image
        resized_img = image1.resize((640, 640))

        # Make a prediction
        results = model(resized_img)

        # Display or save the results for each image
        plt.imshow(resized_img)
        plt.title(f"Results for {filename}")
        plt.show()
# Out:
# 0: 640x640 NotGlued 1.00, Glued 0.00, 34.0ms
# Speed: 10.0ms preprocess, 34.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# 0: 640x640 Glued 0.89, NotGlued 0.11, 40.0ms
# Speed: 11.0ms preprocess, 40.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# 0: 640x640 NotGlued 1.00, Glued 0.00, 45.0ms
# Speed: 9.0ms preprocess, 45.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# 0: 640x640 Glued 0.84, NotGlued 0.16, 47.5ms
# Speed: 9.0ms preprocess, 47.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# 0: 640x640 Glued 0.90, NotGlued 0.10, 31.0ms
# Speed: 5.5ms preprocess, 31.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# 0: 640x640 Glued 0.60, NotGlued 0.40, 30.0ms
# Speed: 7.0ms preprocess, 30.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# 0: 640x640 NotGlued 0.97, Glued 0.03, 46.0ms
# ...
